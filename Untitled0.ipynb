# %%
# !pip install BeautifulSoup4
# !pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (4.9.1)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL = 'https://odel.lk/deal-products'
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'lxml')

data = pd.DataFrame(columns=['Product ID', 'Product Name', 'Current Price', 'Previous Price', 'Discount'])
cards = soup.find_all('div', class_='col-sm-6 col-md-4 col-lg-3 p-b-35 product-tile-search')

for card in cards:
  discount = card.find('div', class_='product_tag_discount').text
  prod_no = card.find('div', class_='block2-pic hov-img0').a['href'].split('/')[-1]
  prod_name = card.find('div', class_='block2-txt-child1 flex-col-l').a.text.strip()

  price = card.find('span', class_='stext-105 cl3').text.strip()
  prev_price = card.find('del').text.strip()

  data_dict = {
      'Product ID': prod_no,
      'Product Name': prod_name,
      'Current Price': price,
      'Previous Price': prev_price,
      'Discount': discount
  }

  df = pd.DataFrame(data_dict, index=[0])
  data = data.append(df, ignore_index=True)


  print(f"Discount: {discount} | Product ID: {prod_no} | Product Name: {prod_name} | Previous Price: {prev_price} | Price: {price}")
# Out:
# Discount: 25% | Product ID: 3069 | Product Name: Beige Colour Linen Serviette | Previous Price: LKR 550 | Price: LKR 413
# Discount: 25% | Product ID: 16640 | Product Name: Odel White Colour Milk Storage Ceramic Jar | Previous Price: LKR 1,750 | Price: LKR 1,313
# Discount: 25% | Product ID: 32439 | Product Name: Odel White Slim Fit Polo | Previous Price: LKR 4,290 | Price: LKR 3,218
# Discount: 25% | Product ID: 32440 | Product Name: Odel Red Regular Fit Polo | Previous Price: LKR 4,290 | Price: LKR 3,218
# Discount: 25% | Product ID: 32441 | Product Name: Odel Black Slim Fit Polo | Previous Price: LKR 4,290 | Price: LKR 3,218
# Discount: 25% | Product ID: 33012 | Product Name: Odel Blue Tie | Previous Price: LKR 1,490 | Price: LKR 1,118
# Discount: 25% | Product ID: 33055 | Product Name: Odel Red Bow | Previous Price: LKR 600 | Price: LKR 450
# Discount: 25% | Product ID: 33149 | Product Name: Odel Ornament Ceramic Cow | Previous Price: LKR 2,250 | Price: LKR 1,688
# Discount: 25% | Product ID: 33171 | Product Name: Odel Tea Light Holder 4 On Wooden Stand | Previous Price: LKR 5,250 | Price: LKR 3,938
# Discount: 25% | Product ID: 33189 | Product Name: Odel Salad Plate Square Melamine Black | Previous Price: LKR 1,750 | Price: LKR 1,313
# Discount: 25% | Product ID: 33192 | Product Name: Odel Salad Plate Round Melamine Black | Previous Price: LKR 1,450 | Price: LKR 1,088
# Discount: 25% | Product ID: 34855 | Product Name: Odel Solid Color Polo | Previous Price: LKR 4,290 | Price: LKR 3,218
# Discount: 25% | Product ID: 35205 | Product Name: Tara Matt Red Knee Length Skirt | Previous Price: LKR 3,990 | Price: LKR 2,993
# Discount: 25% | Product ID: 35743 | Product Name: Biconic Basic Boyfriend Fit Tshirt | Previous Price: LKR 1,990 | Price: LKR 1,493
# Discount: 25% | Product ID: 36832 | Product Name: Typhoon Metal Coffee Storage Jar With Henrik Copper Lid | Previous Price: LKR 5,250 | Price: LKR 3,938
# Discount: 25% | Product ID: 39138 | Product Name: Odel Stripes Band Collar Long Sleeves Shirt | Previous Price: LKR 4,850 | Price: LKR 3,638
# Discount: 25% | Product ID: 41243 | Product Name: Odel Green Elephants on White Ceramic Mug | Previous Price: LKR 1,000 | Price: LKR 750
# Discount: 25% | Product ID: 42881 | Product Name: Biconic Hard Cover Note Book | Previous Price: LKR 1,490 | Price: LKR 1,118
# Discount: 25% | Product ID: 43401 | Product Name: Odel Bath Sheet Green 80X168Cm | Previous Price: LKR 4,950 | Price: LKR 3,713
# Discount: 25% | Product ID: 43405 | Product Name: Odel Bath Sheet L.Green 80X168CmTerry Towel | Previous Price: LKR 4,950 | Price: LKR 3,713
# Discount: 25% | Product ID: 43406 | Product Name: Odel Lemon Green 70X140Cm Terry Bath Towel | Previous Price: LKR 3,450 | Price: LKR 2,588
# Discount: 25% | Product ID: 43408 | Product Name: Odel Face L.Green 30X30Cm  Terry Towel | Previous Price: LKR 450 | Price: LKR 338
# Discount: 25% | Product ID: 43409 | Product Name: Odel Bath Sheet Pink 80X168Cm Terry Towel | Previous Price: LKR 4,950 | Price: LKR 3,713
# Discount: 25% | Product ID: 43421 | Product Name: Odel Lilac 80X168Cm Terry Bath Sheet Towel | Previous Price: LKR 4,950 | Price: LKR 3,713
# Discount: 25% | Product ID: 43424 | Product Name: Odel Lilac 30X30Cm Terry Face Towel | Previous Price: LKR 450 | Price: LKR 338
# Discount: 25% | Product ID: 43463 | Product Name: Odel White Classic 2X4' Pillar Candle | Previous Price: LKR 500 | Price: LKR 375
# Discount: 25% | Product ID: 48943 | Product Name: Biconic  Sleeveless Crop Top | Previous Price: LKR 1,490 | Price: LKR 1,118
# Discount: 25% | Product ID: 49042 | Product Name: Odel Brown Single Pack Socks | Previous Price: LKR 450 | Price: LKR 338
# Discount: 25% | Product ID: 49055 | Product Name: Odel Single Pack Socks | Previous Price: LKR 650 | Price: LKR 488
# Discount: 25% | Product ID: 49650 | Product Name: Odel White Bow | Previous Price: LKR 200 | Price: LKR 150
# Discount: 25% | Product ID: 49651 | Product Name: Odel Black Bow | Previous Price: LKR 750 | Price: LKR 563
# Discount: 25% | Product ID: 49657 | Product Name: Odel Green Basic Polo | Previous Price: LKR 4,290 | Price: LKR 3,218
# Discount: 25% | Product ID: 49658 | Product Name: Odel Blue Basic Polo | Previous Price: LKR 4,290 | Price: LKR 3,218
# Discount: 25% | Product ID: 49666 | Product Name: Odel Navy Blue Regular Fit Pique Polo | Previous Price: LKR 4,290 | Price: LKR 3,218
# Discount: 25% | Product ID: 50311 | Product Name: Tara Royal Blue Waist Gathered Sleeveless Top | Previous Price: LKR 3,490 | Price: LKR 2,618
# Discount: 25% | Product ID: 51607 | Product Name: Tara Navy   Side Tie Up Mini Dress | Previous Price: LKR 2,790 | Price: LKR 2,093
# Discount: 25% | Product ID: 51610 | Product Name: Tara Black Shift  Mini Dress | Previous Price: LKR 5,950 | Price: LKR 4,463
# Discount: 25% | Product ID: 51615 | Product Name: Tara Green Side Slit  Long Sleeve Top | Previous Price: LKR 6,490 | Price: LKR 4,868
# Discount: 25% | Product ID: 51970 | Product Name: Biconic Graphic Top | Previous Price: LKR 1,690 | Price: LKR 1,268
# Discount: 25% | Product ID: 51974 | Product Name: Biconic Bicycle Short | Previous Price: LKR 1,490 | Price: LKR 1,118

# %%
data
# Out:
#    Product ID                                       Product Name  \
# 0        3069                       Beige Colour Linen Serviette
# 1       16640         Odel White Colour Milk Storage Ceramic Jar
# 2       32439                           Odel White Slim Fit Polo
# 3       32440                          Odel Red Regular Fit Polo
# 4       32441                           Odel Black Slim Fit Polo
# 5       33012                                      Odel Blue Tie
# 6       33055                                       Odel Red Bow
# 7       33149                          Odel Ornament Ceramic Cow
# 8       33171            Odel Tea Light Holder 4 On Wooden Stand
# 9       33189             Odel Salad Plate Square Melamine Black
# 10      33192              Odel Salad Plate Round Melamine Black
# 11      34855                              Odel Solid Color Polo
# 12      35205                    Tara Matt Red Knee Length Skirt
# 13      35743                 Biconic Basic Boyfriend Fit Tshirt
# 14      36832  Typhoon Metal Coffee Storage Jar With Henrik C...
# 15      39138        Odel Stripes Band Collar Long Sleeves Shirt
# 16      41243          Odel Green Elephants on White Ceramic Mug
# 17      42881                       Biconic Hard Cover Note Book
# 18      43401                     Odel Bath Sheet Green 80X168Cm
# 19      43405        Odel Bath Sheet L.Green 80X168CmTerry Towel
# 20      43406         Odel Lemon Green 70X140Cm Terry Bath Towel
# 21      43408             Odel Face L.Green 30X30Cm  Terry Towel
# 22      43409          Odel Bath Sheet Pink 80X168Cm Terry Towel
# 23      43421         Odel Lilac 80X168Cm Terry Bath Sheet Towel
# 24      43424                Odel Lilac 30X30Cm Terry Face Towel
# 25      43463              Odel White Classic 2X4' Pillar Candle
# 26      48943                       Biconic  Sleeveless Crop Top
# 27      49042                       Odel Brown Single Pack Socks
# 28      49055                             Odel Single Pack Socks
# 29      49650                                     Odel White Bow
# 30      49651                                     Odel Black Bow
# 31      49657                              Odel Green Basic Polo
# 32      49658                               Odel Blue Basic Polo
# 33      49666              Odel Navy Blue Regular Fit Pique Polo
# 34      50311      Tara Royal Blue Waist Gathered Sleeveless Top
# 35      51607                 Tara Navy   Side Tie Up Mini Dress
# 36      51610                       Tara Black Shift  Mini Dress
# 37      51615              Tara Green Side Slit  Long Sleeve Top
# 38      51970                                Biconic Graphic Top
# 39      51974                              Biconic Bicycle Short
#
#    Current Price Previous Price Discount
# 0        LKR 413        LKR 550      25%
# 1      LKR 1,313      LKR 1,750      25%
# 2      LKR 3,218      LKR 4,290      25%
# 3      LKR 3,218      LKR 4,290      25%
# 4      LKR 3,218      LKR 4,290      25%
# 5      LKR 1,118      LKR 1,490      25%
# 6        LKR 450        LKR 600      25%
# 7      LKR 1,688      LKR 2,250      25%
# 8      LKR 3,938      LKR 5,250      25%
# 9      LKR 1,313      LKR 1,750      25%
# 10     LKR 1,088      LKR 1,450      25%
# 11     LKR 3,218      LKR 4,290      25%
# 12     LKR 2,993      LKR 3,990      25%
# 13     LKR 1,493      LKR 1,990      25%
# 14     LKR 3,938      LKR 5,250      25%
# 15     LKR 3,638      LKR 4,850      25%
# 16       LKR 750      LKR 1,000      25%
# 17     LKR 1,118      LKR 1,490      25%
# 18     LKR 3,713      LKR 4,950      25%
# 19     LKR 3,713      LKR 4,950      25%
# 20     LKR 2,588      LKR 3,450      25%
# 21       LKR 338        LKR 450      25%
# 22     LKR 3,713      LKR 4,950      25%
# 23     LKR 3,713      LKR 4,950      25%
# 24       LKR 338        LKR 450      25%
# 25       LKR 375        LKR 500      25%
# 26     LKR 1,118      LKR 1,490      25%
# 27       LKR 338        LKR 450      25%
# 28       LKR 488        LKR 650      25%
# 29       LKR 150        LKR 200      25%
# 30       LKR 563        LKR 750      25%
# 31     LKR 3,218      LKR 4,290      25%
# 32     LKR 3,218      LKR 4,290      25%
# 33     LKR 3,218      LKR 4,290      25%
# 34     LKR 2,618      LKR 3,490      25%
# 35     LKR 2,093      LKR 2,790      25%
# 36     LKR 4,463      LKR 5,950      25%
# 37     LKR 4,868      LKR 6,490      25%
# 38     LKR 1,268      LKR 1,690      25%
# 39     LKR 1,118      LKR 1,490      25%

# %%
data.to_excel('Data.xlsx', index=False)
